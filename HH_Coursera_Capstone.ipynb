# %% [markdown]
# # Coursera Capstone - The Battle of Neighborhoods

# %% [markdown]
# ### import libraries

# %%
import numpy as np # library to handle data in a vectorized manner
import time
import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe


# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim 

# !conda install -c conda-forge folium=0.5.0 --yes 
import folium
from folium import plugins

import matplotlib.cm as cm
import matplotlib.colors as colors
import seaborn as sns
from sklearn.cluster import KMeans
print('Libraries imported.')
# Out:
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Libraries imported.

# %%
address = 'Abu Dhabi, United Arab Emirates'
geolocator = Nominatim()
location = geolocator.geocode(address)
AD_latitude = location.latitude
AD_longitude = location.longitude
print('The geograpical coordinate of Abu Dhabi home are {}, {}.'.format(AD_latitude, AD_longitude))
# Out:
# C:\Users\HaniHadi\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: Using Nominatim with the default "geopy/1.21.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
# The geograpical coordinate of Abu Dhabi home are 24.4747961, 54.3705762.

# %%
neighborhood_latitude=AD_latitude
neighborhood_longitude=AD_longitude

# %%
CLIENT_ID = 'XXXXXXXXXXX' # your Foursquare ID
CLIENT_SECRET = 'XXXXXXXXXXX' # your Foursquare Secret
VERSION = 'XXXXXXXXXXX' # Foursquare API version

# %%
LIMIT = 150 # limit of number of venues returned by Foursquare API
radius = 1000 # define radius
# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=F4HU4ZHIOSM5WAKVHMKCNJLYTRFLZJ0MPVGEEDEMG2DA22I3&client_secret=ER1EXPG3A4GXKCZ04GVHLWTHMW0VJOAUE00UNVXBAA2KCL04&v=20200320&ll=24.4747961,54.3705762&radius=1000&limit=150'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e7a4c5c47e0d6001bbe2e9c'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Abu Dhabi',
#   'headerFullLocation': 'Abu Dhabi',
#   'headerLocationGranularity': 'city',
#   'totalResults': 107,
#   'suggestedBounds': {'ne': {'lat': 24.483796109000007,
#     'lng': 54.38044629624306},
#    'sw': {'lat': 24.46579609099999, 'lng': 54.36070610375695}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4badf1f4f964a5209d743be3',
#        'name': 'Starbucks (ستاربكس)',
#        'location': {'address': 'Street No.4, Muroor Road',
#         'lat': 24.47742978078926,
#         'lng': 54.37162577431702,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.47742978078926,
#           'lng': 54.37162577431702}],
#         'distance': 311,
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Street No.4, Muroor Road',
#          'أبوظبي',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4badf1f4f964a5209d743be3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '581f78ef5d0a1a25cafb55f1',
#        'name': 'Marriott Hotel Downtown, Abu Dhabi',
#        'location': {'address': 'Sheikh Rashid Bin Saeed Street',
#         'lat': 24.470407,
#         'lng': 54.369669,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.470407,
#           'lng': 54.369669}],
#         'distance': 497,
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Sheikh Rashid Bin Saeed Street',
#          'أبوظبي',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-581f78ef5d0a1a25cafb55f1-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cd5331bb2a4370461537c44',
#        'name': 'Hardees',
#        'location': {'address': 'Near Iranian School',
#         'crossStreet': 'Airport Road',
#         'lat': 24.47338736899542,
#         'lng': 54.36777740267489,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.47338736899542,
#           'lng': 54.36777740267489}],
#         'distance': 324,
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Near Iranian School (Airport Road)',
#          'أبوظبي',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cd5331bb2a4370461537c44-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f97ce81e4b03f3dd04fc9d4',
#        'name': 'Jumeirah Etihad Tower',
#        'location': {'address': 'Etihad Towers',
#         'lat': 24.476050549580535,
#         'lng': 54.36771620965869,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.476050549580535,
#           'lng': 54.36771620965869}],
#         'distance': 321,
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Etihad Towers',
#          'أبوظبي',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f97ce81e4b03f3dd04fc9d4-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5076fb50e4b0510906711dd2',
#        'name': 'Porters Pub',
#        'location': {'address': 'Grand Millenium Al Wahda',
#         'crossStreet': '11th',
#         'lat': 24.471808741468507,
#         'lng': 54.373367227915516,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.471808741468507,
#           'lng': 54.373367227915516}],
#         'distance': 436,
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Grand Millenium Al Wahda (11th)',
#          'أبوظبي',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'shortName': 'Pub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5076fb50e4b0510906711dd2-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '586a83210037eb4944feae62',
#        'name': 'Seven Hotpot',
#        'location': {'lat': 24.47178719925376,
#         'lng': 54.372430823380085,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.47178719925376,
#           'lng': 54.372430823380085}],
#         'distance': 384,
#         'cc': 'AE',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-586a83210037eb4944feae62-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51913280498e31f5ebc56846',
#        'name': 'Paul',
#        'location': {'address': 'Al Wahda Mall',
#         'crossStreet': 'Hazza Bin Zayed Rd',
#         'lat': 24.470538877162145,
#         'lng': 54.372617144776605,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.470538877162145,
#           'lng': 54.372617144776605}],
#         'distance': 517,
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Al Wahda Mall (Hazza Bin Zayed Rd)',
#          'أبوظبي',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51913280498e31f5ebc56846-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52fbb00e11d29f74ef4c2f32',
#        'name': 'Gudee Pizza & Café',
#        'location': {'address': 'Sultan bin Zayed the First St',
#         'lat': 24.477860107067364,
#         'lng': 54.37101215603044,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.477860107067364,
#           'lng': 54.37101215603044}],
#         'distance': 343,
#         'cc': 'AE',
#         'neighborhood': 'Al Dhafrah',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Sultan bin Zayed the First St',
#          'أبوظبي',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52fbb00e11d29f74ef4c2f32-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '589b2c7b6ad5a176dd15f007',
#        'name': 'Bosphorus (البوسفور)',
#        'location': {'address': 'Defence St',
#         'lat': 24.474395143854608,
#         'lng': 54.37592108689771,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.474395143854608,
#           'lng': 54.37592108689771}],
#         'distance': 543,
#         'postalCode': '30069',
#         'cc': 'AE',
#         'neighborhood': 'Istanbul Supermarket',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Defence St',
#          'أبوظبي',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4f04af1f2fb6e1c99f3db0bb',
#          'name': 'Turkish Restaurant',
#          'pluralName': 'Turkish Restaurants',
#          'shortName': 'Turkish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/turkish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-589b2c7b6ad5a176dd15f007-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '512a3c31e4b0c51f9dd03870',
#        'name': 'Sofra Istanbul (سفرة اسطنبول)',
#        'location': {'address': 'Muroor road',
#         'lat': 24.477603654665753,
#         'lng': 54.37140830085203,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.477603654665753,
#           'lng': 54.37140830085203}],
#         'distance': 323,
#         'cc': 'AE',
#         'city': 'AbuDhabi',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Muroor road',
#          'AbuDhabi',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4f04af1f2fb6e1c99f3db0bb',
#          'name': 'Turkish Restaurant',
#          'pluralName': 'Turkish Restaurants',
#          'shortName': 'Turkish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/turkish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-512a3c31e4b0c51f9dd03870-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50854152e4b07ddb62fab032',
#        'name': 'H&M',
#        'location': {'address': 'Hazza Bin Zayed St',
#         'crossStreet': 'Hazza Bin Zayed Street',
#         'lat': 24.4701768,
#         'lng': 54.3726101,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.4701768,
#           'lng': 54.3726101}],
#         'distance': 553,
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Hazza Bin Zayed St (Hazza Bin Zayed Street)',
#          'أبوظبي',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d103951735',
#          'name': 'Clothing Store',
#          'pluralName': 'Clothing Stores',
#          'shortName': 'Apparel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50854152e4b07ddb62fab032-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d5e431d196ba0930e76ff55',
#        'name': 'Al Shater Hassan Restaurant',
#        'location': {'address': 'Al Falah 9th Street',
#         'lat': 24.47875027043531,
#         'lng': 54.36956174449322,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.47875027043531,
#           'lng': 54.36956174449322}],
#         'distance': 452,
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Al Falah 9th Street',
#          'أبوظبي',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d10b941735',
#          'name': 'Falafel Restaurant',
#          'pluralName': 'Falafel Restaurants',
#          'shortName': 'Falafel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/falafel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d5e431d196ba0930e76ff55-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dae00466e81e2dffdbeaf19',
#        'name': 'Corniche Bakery',
#        'location': {'lat': 24.47385754704369,
#         'lng': 54.36712114542213,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.47385754704369,
#           'lng': 54.36712114542213}],
#         'distance': 365,
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['أبوظبي', 'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d1c7941735',
#          'name': 'Snack Place',
#          'pluralName': 'Snack Places',
#          'shortName': 'Snacks',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dae00466e81e2dffdbeaf19-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d91d96ed7b1236a28133938',
#        'name': 'Baskin-Robbins',
#        'location': {'address': 'Al Wahda Mall',
#         'crossStreet': 'Airport Road',
#         'lat': 24.47047221793654,
#         'lng': 54.37295617653028,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.47047221793654,
#           'lng': 54.37295617653028}],
#         'distance': 538,
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Al Wahda Mall (Airport Road)',
#          'أبوظبي',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d91d96ed7b1236a28133938-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cf12650cc61a35dba0a139e',
#        'name': 'Grand Millennium Al Wahda',
#        'location': {'address': 'Hazza Bin Zayed Street Al Wahda Complex',
#         'crossStreet': '16th St.',
#         'lat': 24.4716203,
#         'lng': 54.3740392,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.4716203,
#           'lng': 54.3740392}],
#         'distance': 498,
#         'cc': 'AE',
#         'city': 'Dubai',
#         'state': 'Dubai',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Hazza Bin Zayed Street Al Wahda Complex (16th St.)',
#          'Dubai',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cf12650cc61a35dba0a139e-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51b32304498e6345b7a66c16',
#        'name': 'Pappa Roti',
#        'location': {'address': 'Al Wahda Mall',
#         'lat': 24.470286311930934,
#         'lng': 54.37284010221936,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.470286311930934,
#           'lng': 54.37284010221936}],
#         'distance': 551,
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Al Wahda Mall',
#          'أبوظبي',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51b32304498e6345b7a66c16-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b77f3f3f964a520f3af2ee3',
#        'name': 'Al Wahda Mall الوحدة مول',
#        'location': {'address': 'Hazza Bin Zayed St',
#         'crossStreet': 'Sheikh Rashid Bin Saeed Al Maktoum St',
#         'lat': 24.47040591076105,
#         'lng': 54.37300444409947,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.47040591076105,
#           'lng': 54.37300444409947}],
#         'distance': 547,
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Hazza Bin Zayed St (Sheikh Rashid Bin Saeed Al Maktoum St)',
#          'أبوظبي',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b77f3f3f964a520f3af2ee3-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ca38821554b236a68972748',
#        'name': 'Sahar Restaurant',
#        'location': {'address': 'Madinat Zayad',
#         'lat': 24.477870193407245,
#         'lng': 54.366293685598606,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.477870193407245,
#           'lng': 54.366293685598606}],
#         'distance': 552,
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Madinat Zayad',
#          'أبوظبي',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ca38821554b236a68972748-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5052fd49e4b0a133017ec711',
#        'name': 'Najd Palace Restaurant',
#        'location': {'address': 'Al Falah St',
#         'lat': 24.480743890450807,
#         'lng': 54.37240968890591,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.480743890450807,
#           'lng': 54.37240968890591}],
#         'distance': 687,
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Al Falah St',
#          'أبوظبي',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d115941735',
#          'name': 'Middle Eastern Restaurant',
#          'pluralName': 'Middle Eastern Restaurants',
#          'shortName': 'Middle Eastern',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5052fd49e4b0a133017ec711-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '589af2dde0adac5d4e6838bc',
#        'name': 'Jollibee',
#        'location': {'address': 'Al Falah St',
#         'lat': 24.478873051929728,
#         'lng': 54.36928292151129,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.478873051929728,
#           'lng': 54.36928292151129}],
#         'distance': 472,
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Al Falah St',
#          'أبوظبي',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4eb1bd1c3b7b55596b4a748f',
#          'name': 'Filipino Restaurant',
#          'pluralName': 'Filipino Restaurants',
#          'shortName': 'Filipino',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/filipino_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-589af2dde0adac5d4e6838bc-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4df0989eb0fbfee72f3f3e84',
#        'name': "McDonald's (ماكدونالدز)",
#        'location': {'address': 'Al Falah',
#         'lat': 24.478134944150355,
#         'lng': 54.371902849401025,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.478134944150355,
#           'lng': 54.371902849401025}],
#         'distance': 395,
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Al Falah',
#          'أبوظبي',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4df0989eb0fbfee72f3f3e84-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55c1ed54498e82bef7ee1850',
#        'name': 'Corniche Beach, Abu Dhabi',
#        'location': {'lat': 24.478430584837177,
#         'lng': 54.371242482055,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.478430584837177,
#           'lng': 54.371242482055}],
#         'distance': 410,
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['أبوظبي', 'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d1e2941735',
#          'name': 'Beach',
#          'pluralName': 'Beaches',
#          'shortName': 'Beach',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/beach_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55c1ed54498e82bef7ee1850-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '523690bb11d22da9cc5a99a0',
#        'name': 'Al Khabiya Pastries and Falafel',
#        'location': {'address': 'Sultan Bin Zayed The First St',
#         'crossStreet': 'Behind old Red Crescent',
#         'lat': 24.475003414402458,
#         'lng': 54.37398921751616,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.475003414402458,
#           'lng': 54.37398921751616}],
#         'distance': 346,
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Sultan Bin Zayed The First St (Behind old Red Crescent)',
#          'أبوظبي',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d115941735',
#          'name': 'Middle Eastern Restaurant',
#          'pluralName': 'Middle Eastern Restaurants',
#          'shortName': 'Middle Eastern',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-523690bb11d22da9cc5a99a0-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57000a8e498ef963d3beae7d',
#        'name': 'The One Men Spa',
#        'location': {'address': 'Abu Dhabi',
#         'crossStreet': 'Defense Road',
#         'lat': 24.47535675094786,
#         'lng': 54.37703903041514,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.47535675094786,
#           'lng': 54.37703903041514}],
#         'distance': 657,
#         'postalCode': '00971',
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Abu Dhabi (Defense Road)',
#          'أبوظبي',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d1ed941735',
#          'name': 'Spa',
#          'pluralName': 'Spas',
#          'shortName': 'Spa',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57000a8e498ef963d3beae7d-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e2a9e9a52b1b8f1985823b9',
#        'name': 'Sadaf Restourant',
#        'location': {'crossStreet': 'Al Morour St',
#         'lat': 24.477689267226697,
#         'lng': 54.37044160298044,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.477689267226697,
#           'lng': 54.37044160298044}],
#         'distance': 322,
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['أبوظبي', 'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d115941735',
#          'name': 'Middle Eastern Restaurant',
#          'pluralName': 'Middle Eastern Restaurants',
#          'shortName': 'Middle Eastern',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e2a9e9a52b1b8f1985823b9-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '504767c7e4b0deba9aa7c8fb',
#        'name': 'Farghaly Fruits',
#        'location': {'crossStreet': 'Defense Street',
#         'lat': 24.47478465065937,
#         'lng': 54.37648791277401,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.47478465065937,
#           'lng': 54.37648791277401}],
#         'distance': 598,
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Defense Street',
#          'أبوظبي',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d112941735',
#          'name': 'Juice Bar',
#          'pluralName': 'Juice Bars',
#          'shortName': 'Juice Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/juicebar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-504767c7e4b0deba9aa7c8fb-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '508fb80ee4b0784a931e058a',
#        'name': 'Virgin Megastore ڤيرجن ميجاستور',
#        'location': {'address': 'Al Wahda Mall',
#         'lat': 24.470214860255087,
#         'lng': 54.37406163985815,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.470214860255087,
#           'lng': 54.37406163985815}],
#         'distance': 620,
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Al Wahda Mall',
#          'أبوظبي',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d1fe941735',
#          'name': 'Music Store',
#          'pluralName': 'Music Stores',
#          'shortName': 'Music Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/music_instruments_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-508fb80ee4b0784a931e058a-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '574b2105cd1031dbbc320c58',
#        'name': 'Off The Hook',
#        'location': {'crossStreet': 'Sheikh Rasheed Bin Saeed Road, Airport Road',
#         'lat': 24.473907916046088,
#         'lng': 54.366442547588676,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.473907916046088,
#           'lng': 54.366442547588676}],
#         'distance': 430,
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Sheikh Rasheed Bin Saeed Road, Airport Road',
#          'أبوظبي',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'shortName': 'Seafood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-574b2105cd1031dbbc320c58-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d7cf69534f7721e2af6ce25',
#        'name': 'Al Sultan Bakeries & Market',
#        'location': {'lat': 24.474715565100183,
#         'lng': 54.37410079557515,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.474715565100183,
#           'lng': 54.37410079557515}],
#         'distance': 357,
#         'cc': 'AE',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d1c0941735',
#          'name': 'Mediterranean Restaurant',
#          'pluralName': 'Mediterranean Restaurants',
#          'shortName': 'Mediterranean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d7cf69534f7721e2af6ce25-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cfcc529c6cca35da9329332',
#        'name': 'Al Sultan Restaurant',
#        'location': {'address': 'Abu Dhabi',
#         'crossStreet': 'Defense Road',
#         'lat': 24.475079,
#         'lng': 54.377103,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.475079,
#           'lng': 54.377103}],
#         'distance': 662,
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Abu Dhabi (Defense Road)',
#          'أبوظبي',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d115941735',
#          'name': 'Middle Eastern Restaurant',
#          'pluralName': 'Middle Eastern Restaurants',
#          'shortName': 'Middle Eastern',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cfcc529c6cca35da9329332-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dd66178c65bee535a96e389',
#        'name': 'Porto Bello',
#        'location': {'address': 'Grand Millennium Al Wahda',
#         'crossStreet': 'Hazza Bin Zayed Street',
#         'lat': 24.47161076850749,
#         'lng': 54.3739356487083,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.47161076850749,
#           'lng': 54.3739356487083}],
#         'distance': 491,
#         'cc': 'AE',
#         'neighborhood': 'Al Wahda',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Grand Millennium Al Wahda (Hazza Bin Zayed Street)',
#          'أبوظبي',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dd66178c65bee535a96e389-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d39dfa6ad8860fc15971252',
#        'name': 'Al Falah Plaza الفلاح بلازا',
#        'location': {'address': 'Al Muroor Street',
#         'lat': 24.478177305167424,
#         'lng': 54.37193870999531,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.478177305167424,
#           'lng': 54.37193870999531}],
#         'distance': 400,
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Al Muroor Street',
#          'أبوظبي',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d1f6941735',
#          'name': 'Department Store',
#          'pluralName': 'Department Stores',
#          'shortName': 'Department Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d39dfa6ad8860fc15971252-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '517ae9aa498ea18ae91cc316',
#        'name': 'Nasar Restaurant مطعم ناصر',
#        'location': {'address': 'Nasar Restaurant',
#         'crossStreet': 'Airport road',
#         'lat': 24.472078224523248,
#         'lng': 54.36858893329629,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.472078224523248,
#           'lng': 54.36858893329629}],
#         'distance': 363,
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Nasar Restaurant (Airport road)',
#          'أبوظبي',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-517ae9aa498ea18ae91cc316-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5aa55e37772fbc53118ec974',
#        'name': 'Grand Millenium Club Lounge',
#        'location': {'lat': 24.47098395365584,
#         'lng': 54.37436522044025,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.47098395365584,
#           'lng': 54.37436522044025}],
#         'distance': 572,
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['أبوظبي', 'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d1d5941735',
#          'name': 'Hotel Bar',
#          'pluralName': 'Hotel Bars',
#          'shortName': 'Hotel Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5aa55e37772fbc53118ec974-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d344b102e56236a58782db4',
#        'name': 'Muallim Hasan معلم حسن',
#        'location': {'address': 'Al Falah St.',
#         'lat': 24.47740940945206,
#         'lng': 54.36754210614969,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.47740940945206,
#           'lng': 54.36754210614969}],
#         'distance': 423,
#         'cc': 'AE',
#         'city': 'Abu Dhabi',
#         'state': 'AD',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Al Falah St.',
#          'Abu Dhabi',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d115941735',
#          'name': 'Middle Eastern Restaurant',
#          'pluralName': 'Middle Eastern Restaurants',
#          'shortName': 'Middle Eastern',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d344b102e56236a58782db4-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '523a063911d262784e7b59a0',
#        'name': 'VOX GOLD',
#        'location': {'address': 'Marina Mall',
#         'lat': 24.475162761141092,
#         'lng': 54.36596216647192,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.475162761141092,
#           'lng': 54.36596216647192}],
#         'distance': 469,
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Marina Mall',
#          'أبوظبي',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d17f941735',
#          'name': 'Movie Theater',
#          'pluralName': 'Movie Theaters',
#          'shortName': 'Movie Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-523a063911d262784e7b59a0-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d93647e9213b1f7fa65c746',
#        'name': 'Hankook Korean Restaurant',
#        'location': {'address': 'Defense Rd',
#         'lat': 24.473555746897848,
#         'lng': 54.37700374940629,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.473555746897848,
#           'lng': 54.37700374940629}],
#         'distance': 665,
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Defense Rd',
#          'أبوظبي',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d113941735',
#          'name': 'Korean Restaurant',
#          'pluralName': 'Korean Restaurants',
#          'shortName': 'Korean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d93647e9213b1f7fa65c746-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5746fecdcd1084eabd620d13',
#        'name': 'Al-ulya',
#        'location': {'lat': 24.472885936141843,
#         'lng': 54.37834770794117,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.472885936141843,
#           'lng': 54.37834770794117}],
#         'distance': 815,
#         'cc': 'AE',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5746fecdcd1084eabd620d13-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4db3d62f93a017099dcd16c9',
#        'name': "Magrudy's",
#        'location': {'address': 'Al Wahda Mall',
#         'lat': 24.470358853023495,
#         'lng': 54.37272838815643,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.470358853023495,
#           'lng': 54.37272838815643}],
#         'distance': 539,
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Al Wahda Mall',
#          'أبوظبي',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'shortName': 'Bookstore',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4db3d62f93a017099dcd16c9-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '509e7ff2e4b0bbf7765f4807',
#        'name': 'Bath & Body Works - Al Wahda Mall',
#        'location': {'lat': 24.4693059021757,
#         'lng': 54.3734125040085,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.4693059021757,
#           'lng': 54.3734125040085}],
#         'distance': 675,
#         'cc': 'AE',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d10c951735',
#          'name': 'Cosmetics Shop',
#          'pluralName': 'Cosmetics Shops',
#          'shortName': 'Cosmetics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/beauty_cosmetic_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-509e7ff2e4b0bbf7765f4807-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5183c05a498e392dee78dcea',
#        'name': 'Maven Spa',
#        'location': {'address': 'Al Wahda Mall',
#         'lat': 24.469324794152133,
#         'lng': 54.37352770086916,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.469324794152133,
#           'lng': 54.37352770086916}],
#         'distance': 678,
#         'cc': 'AE',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Al Wahda Mall', 'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d1ed941735',
#          'name': 'Spa',
#          'pluralName': 'Spas',
#          'shortName': 'Spa',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'primary': True}],
# ...
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-520e300111d290eeb04d51fb-85'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f59c937e4b04e4607cd248f',
#        'name': 'Ibn Al Badiya Restuarant',
#        'location': {'lat': 24.4795430525016,
#         'lng': 54.37090611187201,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.4795430525016,
#           'lng': 54.37090611187201}],
#         'distance': 529,
#         'cc': 'AE',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d115941735',
#          'name': 'Middle Eastern Restaurant',
#          'pluralName': 'Middle Eastern Restaurants',
#          'shortName': 'Middle Eastern',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f59c937e4b04e4607cd248f-86'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50e553e8e4b0c88a534499c8',
#        'name': 'Pandora',
#        'location': {'address': 'Al Wahda Mall',
#         'lat': 24.46961964026585,
#         'lng': 54.37313258829968,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.46961964026585,
#           'lng': 54.37313258829968}],
#         'distance': 631,
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Al Wahda Mall',
#          'أبوظبي',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d111951735',
#          'name': 'Jewelry Store',
#          'pluralName': 'Jewelry Stores',
#          'shortName': 'Jewelry',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/jewelry_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50e553e8e4b0c88a534499c8-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c5c4939857ca5935ea0c9cb',
#        'name': '711Furnitures',
#        'location': {'lat': 24.475783984498136,
#         'lng': 54.36505990255385,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.475783984498136,
#           'lng': 54.36505990255385}],
#         'distance': 569,
#         'cc': 'AE',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d1f8941735',
#          'name': 'Furniture / Home Store',
#          'pluralName': 'Furniture / Home Stores',
#          'shortName': 'Furniture / Home',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c5c4939857ca5935ea0c9cb-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fa53d47e4b0b487cddf60ab',
#        'name': 'batangas restaurant',
#        'location': {'address': 'Al falah st. Old passport road',
#         'crossStreet': 'Near Taha Medical Center',
#         'lat': 24.480471991851903,
#         'lng': 54.37058576062511,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.480471991851903,
#           'lng': 54.37058576062511}],
#         'distance': 631,
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Al falah st. Old passport road (Near Taha Medical Center)',
#          'أبوظبي',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fa53d47e4b0b487cddf60ab-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e576d2ad16491e0ae48a15d',
#        'name': 'Madinat Zayed Vegetables, Meat & Fish Market',
#        'location': {'address': 'Madinat Zayed',
#         'lat': 24.48090563185383,
#         'lng': 54.36612540669929,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.48090563185383,
#           'lng': 54.36612540669929}],
#         'distance': 816,
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Madinat Zayed',
#          'أبوظبي',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d1fa941735',
#          'name': 'Farmers Market',
#          'pluralName': 'Farmers Markets',
#          'shortName': "Farmer's Market",
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_farmersmarket_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e576d2ad16491e0ae48a15d-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52e119c9498eaa74b206129a',
#        'name': 'London Dairy',
#        'location': {'address': 'Al-Wahda Mall',
#         'lat': 24.46969773933648,
#         'lng': 54.37401892460856,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.46969773933648,
#           'lng': 54.37401892460856}],
#         'distance': 666,
#         'cc': 'AE',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Al-Wahda Mall', 'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52e119c9498eaa74b206129a-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50c76739e4b0f02263d923b2',
#        'name': 'Sacoor Brothers',
#        'location': {'address': 'Al Wahda Mall - First Floor E 146',
#         'lat': 24.469799922583732,
#         'lng': 54.374227161664564,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.469799922583732,
#           'lng': 54.374227161664564}],
#         'distance': 667,
#         'cc': 'AE',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Al Wahda Mall - First Floor E 146',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d103951735',
#          'name': 'Clothing Store',
#          'pluralName': 'Clothing Stores',
#          'shortName': 'Apparel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50c76739e4b0f02263d923b2-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50e3ff63e4b0e3d2da968140',
#        'name': 'iSTYLE',
#        'location': {'address': 'Wahda Mall',
#         'lat': 24.46934112119158,
#         'lng': 54.37343685188537,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.46934112119158,
#           'lng': 54.37343685188537}],
#         'distance': 672,
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Wahda Mall',
#          'أبوظبي',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d122951735',
#          'name': 'Electronics Store',
#          'pluralName': 'Electronics Stores',
#          'shortName': 'Electronics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50e3ff63e4b0e3d2da968140-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51fa8fe9498e575b73df8d84',
#        'name': 'Du Al Wahda Mall',
#        'location': {'lat': 24.469331947474817,
#         'lng': 54.37341557413188,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.469331947474817,
#           'lng': 54.37341557413188}],
#         'distance': 672,
#         'cc': 'AE',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['الإمارات العربية المتحدة']},
#        'categories': [{'id': '4f04afc02fb6e1c99f3db0bc',
#          'name': 'Mobile Phone Shop',
#          'pluralName': 'Mobile Phone Shops',
#          'shortName': 'Mobile Phones',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mobilephoneshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51fa8fe9498e575b73df8d84-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '509d1afde4b005ecff716778',
#        'name': 'iconic',
#        'location': {'address': 'wahda mall',
#         'lat': 24.46926074931822,
#         'lng': 54.37334616242049,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.46926074931822,
#           'lng': 54.37334616242049}],
#         'distance': 677,
#         'cc': 'AE',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['wahda mall', 'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d1f6941735',
#          'name': 'Department Store',
#          'pluralName': 'Department Stores',
#          'shortName': 'Department Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-509d1afde4b005ecff716778-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dc5134dd164eb9c9fe53966',
#        'name': 'Etisalat',
#        'location': {'address': 'Al Wahda Mall',
#         'lat': 24.469291291666284,
#         'lng': 54.37350597519745,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.469291291666284,
#           'lng': 54.37350597519745}],
#         'distance': 680,
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Al Wahda Mall',
#          'أبوظبي',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4f04afc02fb6e1c99f3db0bc',
#          'name': 'Mobile Phone Shop',
#          'pluralName': 'Mobile Phone Shops',
#          'shortName': 'Mobile Phones',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mobilephoneshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dc5134dd164eb9c9fe53966-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5c632fc8ecb3ed002540b281',
#        'name': 'Emirates Post - Abu Dhabi Central Post Office',
#        'location': {'address': 'Murour Rd, Zayed City, Al Danah,Beside Gold Souq',
#         'lat': 24.48063,
#         'lng': 54.367794,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.48063,
#           'lng': 54.367794}],
#         'distance': 707,
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Murour Rd, Zayed City, Al Danah,Beside Gold Souq',
#          'أبوظبي',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d172941735',
#          'name': 'Post Office',
#          'pluralName': 'Post Offices',
#          'shortName': 'Post Office',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5c632fc8ecb3ed002540b281-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e98259261af7d268f242f2f',
#        'name': 'Al Khalifa Lebanese Bakeries',
#        'location': {'address': 'Al Falah Street',
#         'lat': 24.480721632886244,
#         'lng': 54.37333548370097,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.480721632886244,
#           'lng': 54.37333548370097}],
#         'distance': 716,
#         'cc': 'AE',
#         'city': 'أبوظبي',
#         'state': 'أبوظبي',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Al Falah Street',
#          'أبوظبي',
#          'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e98259261af7d268f242f2f-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f2accace4b05b4a410d02e9',
#        'name': 'Baskin-Robbins',
#        'location': {'address': 'Madinat Zayed',
#         'lat': 24.481144998312192,
#         'lng': 54.37189920884899,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.481144998312192,
#           'lng': 54.37189920884899}],
#         'distance': 719,
#         'cc': 'AE',
#         'country': 'الإمارات العربية المتحدة',
#         'formattedAddress': ['Madinat Zayed', 'الإمارات العربية المتحدة']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f2accace4b05b4a410d02e9-99'}]}]}}

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
SGnearby_venues = json_normalize(venues)

filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
SGnearby_venues =SGnearby_venues.loc[:, filtered_columns]

SGnearby_venues['venue.categories'] = SGnearby_venues.apply(get_category_type, axis=1)

SGnearby_venues.columns = [col.split(".")[-1] for col in SGnearby_venues.columns]

SGnearby_venues.shape
# Out:
# (100, 4)

# %%
SGnearby_venues.head(10)
# Out:
#                                  name            categories        lat  \
# 0                 Starbucks (ستاربكس)           Coffee Shop  24.477430
# 1  Marriott Hotel Downtown, Abu Dhabi                 Hotel  24.470407
# 2                             Hardees  Fast Food Restaurant  24.473387
# 3               Jumeirah Etihad Tower                 Hotel  24.476051
# 4                         Porters Pub                   Pub  24.471809
# 5                        Seven Hotpot    Chinese Restaurant  24.471787
# 6                                Paul     French Restaurant  24.470539
# 7                  Gudee Pizza & Café           Pizza Place  24.477860
# 8                Bosphorus (البوسفور)    Turkish Restaurant  24.474395
# 9       Sofra Istanbul (سفرة اسطنبول)    Turkish Restaurant  24.477604
#
#          lng
# 0  54.371626
# 1  54.369669
# 2  54.367777
# 3  54.367716
# 4  54.373367
# 5  54.372431
# 6  54.372617
# 7  54.371012
# 8  54.375921
# 9  54.371408

# %%
latitude=neighborhood_latitude
longitude=neighborhood_longitude
# create map of Abu Dhabi place  using latitude and longitude values
map_sg = folium.Map(location=[latitude, longitude], zoom_start=18)
# add markers to map
for lat, lng, label in zip(SGnearby_venues['lat'], SGnearby_venues['lng'], SGnearby_venues['name']):
    label = folium.Popup(label, parse_html=True)
    folium.RegularPolygonMarker(
        [lat, lng],
        number_of_sides=30,
        radius=7,
        popup=label,
        color='blue',
        fill_color='#0f0f0f',
        fill_opacity=0.6,
    ).add_to(map_sg)  
    
map_sg
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Read csv file with clustered neighborhoods with geodata
manhattan_data  = pd.read_csv('mh_neigh_data.csv') 
manhattan_data.head()
# Out:
#      Borough        Neighborhood   Latitude  Longitude  Cluster Labels
# 0  Manhattan         Marble Hill  40.876551 -73.910660               2
# 1  Manhattan           Chinatown  40.715618 -73.994279               2
# 2  Manhattan  Washington Heights  40.851903 -73.936900               4
# 3  Manhattan              Inwood  40.867684 -73.921210               3
# 4  Manhattan    Hamilton Heights  40.823604 -73.949688               0

# %%
manhattan_data.tail()
# Out:
#       Borough     Neighborhood   Latitude  Longitude  Cluster Labels
# 35  Manhattan       Turtle Bay  40.752042 -73.967708               3
# 36  Manhattan       Tudor City  40.746917 -73.971219               3
# 37  Manhattan  Stuyvesant Town  40.731000 -73.974052               4
# 38  Manhattan         Flatiron  40.739673 -73.990947               3
# 39  Manhattan     Hudson Yards  40.756658 -74.000111               2

# %%
manhattan_merged = pd.read_csv('manhattan_merged.csv')
manhattan_merged.head()
# Out:
#      Borough        Neighborhood   Latitude  Longitude  Cluster Labels  \
# 0  Manhattan         Marble Hill  40.876551 -73.910660               2
# 1  Manhattan           Chinatown  40.715618 -73.994279               2
# 2  Manhattan  Washington Heights  40.851903 -73.936900               4
# 3  Manhattan              Inwood  40.867684 -73.921210               3
# 4  Manhattan    Hamilton Heights  40.823604 -73.949688               0
#
#   1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0           Coffee Shop        Discount Store           Yoga Studio
# 1    Chinese Restaurant          Cocktail Bar    Dim Sum Restaurant
# 2                  Café                Bakery     Mobile Phone Shop
# 3    Mexican Restaurant                Lounge           Pizza Place
# 4    Mexican Restaurant           Coffee Shop                  Café
#
#   4th Most Common Venue  5th Most Common Venue 6th Most Common Venue  \
# 0            Steakhouse        Supplement Shop        Tennis Stadium
# 1   American Restaurant  Vietnamese Restaurant    Salon / Barbershop
# 2           Pizza Place         Sandwich Place                  Park
# 3                  Café               Wine Bar                Bakery
# 4         Deli / Bodega            Pizza Place          Liquor Store
#
#   7th Most Common Venue      8th Most Common Venue 9th Most Common Venue  \
# 0            Shoe Store                        Gym                  Bank
# 1          Noodle House                     Bakery       Bubble Tea Shop
# 2                   Gym  Latin American Restaurant      Tapas Restaurant
# 3   American Restaurant                       Park    Frozen Yogurt Shop
# 4     Indian Restaurant           Sushi Restaurant        Sandwich Place
#
#   10th Most Common Venue
# 0     Seafood Restaurant
# 1         Ice Cream Shop
# 2     Mexican Restaurant
# 3     Spanish Restaurant
# 4            Yoga Studio

# %%
# create map of Manhattan using latitude and longitude values from Nominatim
man_latitude= 40.7308619
man_longitude= -73.9871558 

latitude= man_latitude
longitude= man_longitude 

kclusters=5
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=13)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(manhattan_merged['Latitude'], manhattan_merged['Longitude'], manhattan_merged['Neighborhood'], manhattan_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=30,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
  # add markers for rental places to map
for lat, lng, label in zip(manhattan_data['Latitude'], manhattan_data['Longitude'], manhattan_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=10,
        popup=label,
        color='red',
        fill=True,
        fill_color='#2765cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_clusters) 
    
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
## kk is the cluster number to explore
kk = 2
manhattan_merged.loc[manhattan_merged['Cluster Labels'] == kk, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]]
# Out:
#            Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0           Marble Hill           Coffee Shop        Discount Store
# 1             Chinatown    Chinese Restaurant          Cocktail Bar
# 6        Central Harlem    African Restaurant    Seafood Restaurant
# 9             Yorkville           Coffee Shop                   Gym
# 14              Clinton               Theater    Italian Restaurant
# 23                 Soho        Clothing Store              Boutique
# 26  Morningside Heights           Coffee Shop   American Restaurant
# 34         Sutton Place  Gym / Fitness Center    Italian Restaurant
# 39         Hudson Yards           Coffee Shop    Italian Restaurant
#
#      3rd Most Common Venue 4th Most Common Venue  5th Most Common Venue  \
# 0              Yoga Studio            Steakhouse        Supplement Shop
# 1       Dim Sum Restaurant   American Restaurant  Vietnamese Restaurant
# 6        French Restaurant   American Restaurant         Cosmetics Shop
# 9                      Bar    Italian Restaurant       Sushi Restaurant
# 14             Coffee Shop   American Restaurant   Gym / Fitness Center
# 23           Women's Store            Shoe Store            Men's Store
# 26                    Park             Bookstore            Pizza Place
# 34  Furniture / Home Store     Indian Restaurant           Dessert Shop
# 39                   Hotel               Theater    American Restaurant
#
#      6th Most Common Venue 7th Most Common Venue     8th Most Common Venue  \
# 0           Tennis Stadium            Shoe Store                       Gym
# 1       Salon / Barbershop          Noodle House                    Bakery
# 6       Chinese Restaurant           Event Space              Liquor Store
# 9              Pizza Place    Mexican Restaurant             Deli / Bodega
# 14                   Hotel             Wine Shop                       Spa
# 23  Furniture / Home Store    Italian Restaurant  Mediterranean Restaurant
# 26          Sandwich Place          Burger Joint                      Café
# 34     American Restaurant                Bakery                 Juice Bar
# 39                    Café  Gym / Fitness Center           Thai Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 0                   Bank     Seafood Restaurant
# 1        Bubble Tea Shop         Ice Cream Shop
# 6               Beer Bar   Gym / Fitness Center
# 9    Japanese Restaurant                    Pub
# 14                   Gym          Indie Theater
# 23           Art Gallery          Design Studio
# 26         Deli / Bodega           Tennis Court
# 34              Boutique       Sushi Restaurant
# 39            Restaurant                    Gym

# %%
# csv files with rental places with basic data but still wihtout geodata ( latitude and longitude)
# pd.read_csv(' le.csv', header=None, nrows=5)
mh_rent=pd.read_csv('MH_flats_price.csv')
mh_rent.head()
# Out:
#              Address             Area  Price_per_ft2  Rooms  Area-ft2  \
# 0  West 105th Street  Upper West Side           2.94    5.0      3400
# 1   East 97th Street  Upper East Side           3.57    3.0      2100
# 2  West 105th Street  Upper West Side           1.89    4.0      2800
# 3        CARMINE ST.     West Village           3.03    2.0      1650
# 4    171 W 23RD ST.           Chelsea           3.45    2.0      1450
#
#    Rent_Price  Lat  Long
# 0       10000  NaN   NaN
# 1        7500  NaN   NaN
# 2        5300  NaN   NaN
# 3        5000  NaN   NaN
# 4        5000  NaN   NaN

# %%
mh_rent.tail()
# Out:
#                   Address                                Area  Price_per_ft2  \
# 139  200 East 72nd Street                Rental in Lenox Hill           5.15
# 140      50 Murray Street            No fee rental in Tribeca           7.11
# 141  300 East 56th Street       No fee rental in Midtown East           3.87
# 142         1930 Broadway  No fee rental in Central Park West           5.06
# 143    33 West 9th Street         Rental in Greenwich Village           6.67
#
#      Rooms  Area-ft2  Rent_Price  Lat  Long
# 139    3.0      1700        8750  NaN   NaN
# 140    2.0      1223        8700  NaN   NaN
# 141    3.0      2100        8118  NaN   NaN
# 142    2.0      1600        8095  NaN   NaN
# 143    2.0      1500       10000  NaN   NaN

# %%
mh_rent=pd.read_csv('MH_rent_latlong.csv')
mh_rent.head()
# Out:
#              Address             Area  Price_per_ft2  Rooms  Area-ft2  \
# 0  West 105th Street  Upper West Side           2.94    5.0      3400
# 1   East 97th Street  Upper East Side           3.57    3.0      2100
# 2  West 105th Street  Upper West Side           1.89    4.0      2800
# 3        CARMINE ST.     West Village           3.03    2.0      1650
# 4    171 W 23RD ST.           Chelsea           3.45    2.0      1450
#
#    Rent_Price        Lat       Long
# 0       10000  40.799771 -73.966213
# 1        7500  40.788585 -73.955277
# 2        5300  40.799771 -73.966213
# 3        5000  40.730523 -74.001873
# 4        5000  40.744118 -73.995299

# %%
mh_rent.tail()
# Out:
#                   Address                                Area  Price_per_ft2  \
# 139  200 East 72nd Street                Rental in Lenox Hill           5.15
# 140      50 Murray Street            No fee rental in Tribeca           7.11
# 141  300 East 56th Street       No fee rental in Midtown East           3.87
# 142         1930 Broadway  No fee rental in Central Park West           5.06
# 143    33 West 9th Street         Rental in Greenwich Village           6.67
#
#      Rooms  Area-ft2  Rent_Price        Lat       Long
# 139    3.0      1700        8750  40.769465 -73.960339
# 140    2.0      1223        8700  40.714051 -74.009608
# 141    3.0      2100        8118  40.758216 -73.965190
# 142    2.0      1600        8095  40.772474 -73.981901
# 143    2.0      1500       10000  40.733691 -73.997323

# %%
import seaborn as sns
sns.distplot(mh_rent['Rent_Price'],bins=15)

# %%
import seaborn as sns
sns.distplot(mh_rent['Price_per_ft2'],bins=15)

# %%
sns.boxplot(x='Rooms', y= 'Rent_Price', data=mh_rent)

# %%
# create map of Manhattan using latitude and longitude values from Nominatim
latitude= man_latitude
longitude= man_longitude

map_manhattan_rent = folium.Map(location=[latitude, longitude], zoom_start=12.5)

# add markers to map
for lat, lng, label in zip(mh_rent['Lat'], mh_rent['Long'],'$ ' + mh_rent['Rent_Price'].astype(str)+ ',  '+ mh_rent['Address']):      
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=6,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_manhattan_rent) 
    

map_manhattan_rent
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
latitude= man_latitude
longitude= man_longitude

# create map with clusters
kclusters=5
map_clusters2 = folium.Map(location=[latitude, longitude], zoom_start=13)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(manhattan_merged['Latitude'], manhattan_merged['Longitude'], manhattan_merged['Neighborhood'], manhattan_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=20,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters2)
    

# add markers to map for rental places
for lat, lng, label in zip(mh_rent['Lat'], mh_rent['Long'],'$ ' + mh_rent['Rent_Price'].astype(str)+ mh_rent['Address']):      
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=6,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_clusters2)  
    
    # Adds tool to the top right
from folium.plugins import MeasureControl
map_manhattan_rent.add_child(MeasureControl())

# FMeasurement ruler icon to establish distnces on map
from folium.plugins import FloatImage
url = ('https://media.licdn.com/mpr/mpr/shrinknp_100_100/AAEAAQAAAAAAAAlgAAAAJGE3OTA4YTdlLTkzZjUtNDFjYy1iZThlLWQ5OTNkYzlhNzM4OQ.jpg')
FloatImage(url, bottom=5, left=85).add_to(map_manhattan_rent)

map_clusters2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
## kk is the cluster number to explore
kk = 3
manhattan_merged.loc[manhattan_merged['Cluster Labels'] == kk, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]]
# Out:
#           Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 3               Inwood    Mexican Restaurant                Lounge
# 5       Manhattanville         Deli / Bodega    Italian Restaurant
# 10          Lenox Hill      Sushi Restaurant    Italian Restaurant
# 12     Upper West Side    Italian Restaurant                   Bar
# 16         Murray Hill        Sandwich Place                 Hotel
# 17             Chelsea           Coffee Shop    Italian Restaurant
# 18   Greenwich Village    Italian Restaurant      Sushi Restaurant
# 27            Gramercy    Italian Restaurant            Restaurant
# 29  Financial District           Coffee Shop                 Hotel
# 31                Noho    Italian Restaurant     French Restaurant
# 32        Civic Center  Gym / Fitness Center                Bakery
# 35          Turtle Bay    Italian Restaurant           Coffee Shop
# 36          Tudor City                  Café                  Park
# 38            Flatiron    Italian Restaurant   American Restaurant
#
#      3rd Most Common Venue          4th Most Common Venue  \
# 3              Pizza Place                           Café
# 5       Seafood Restaurant             Mexican Restaurant
# 10             Coffee Shop           Gym / Fitness Center
# 12                  Bakery  Vegetarian / Vegan Restaurant
# 16     Japanese Restaurant           Gym / Fitness Center
# 17          Ice Cream Shop                         Bakery
# 18       French Restaurant                 Clothing Store
# 27  Thrift / Vintage Store                   Cocktail Bar
# 29                     Gym                      Wine Shop
# 31            Cocktail Bar                      Gift Shop
# 32      Italian Restaurant                   Cocktail Bar
# 35              Steakhouse                       Wine Bar
# 36             Pizza Place             Mexican Restaurant
# 38                     Gym           Gym / Fitness Center
#
#    5th Most Common Venue          6th Most Common Venue 7th Most Common Venue  \
# 3               Wine Bar                         Bakery   American Restaurant
# 5       Sushi Restaurant                    Beer Garden           Coffee Shop
# 10           Pizza Place                   Burger Joint         Deli / Bodega
# 12     Indian Restaurant                    Coffee Shop        Cosmetics Shop
# 16           Coffee Shop             Salon / Barbershop          Burger Joint
# 17             Nightclub                        Theater           Art Gallery
# 18    Chinese Restaurant                           Café     Indian Restaurant
# 27            Bagel Shop                    Coffee Shop           Pizza Place
# 29            Steakhouse                            Bar    Italian Restaurant
# 31             Bookstore                  Grocery Store    Mexican Restaurant
# 32     French Restaurant                 Sandwich Place           Coffee Shop
# 35      Sushi Restaurant                          Hotel          Noodle House
# 36      Greek Restaurant               Sushi Restaurant                 Hotel
# 38           Yoga Studio  Vegetarian / Vegan Restaurant                Bakery
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 3                   Park    Frozen Yogurt Shop     Spanish Restaurant
# 5     Falafel Restaurant            Bike Trail        Other Nightlife
# 10                   Gym   Sporting Goods Shop        Thai Restaurant
# 12              Wine Bar    Mexican Restaurant       Sushi Restaurant
# 16     French Restaurant                   Bar     Italian Restaurant
# 17    Seafood Restaurant   American Restaurant                  Hotel
# 18                Bakery    Seafood Restaurant      Electronics Store
# 27    Mexican Restaurant         Grocery Store              Wine Shop
# 29           Pizza Place                  Park   Gym / Fitness Center
# 31                 Hotel      Sushi Restaurant            Coffee Shop
# 32                   Gym           Yoga Studio                   Park
# 35     Indian Restaurant   Japanese Restaurant      French Restaurant
# 36         Deli / Bodega                 Diner                Dog Run
# 38        Clothing Store        Cosmetics Shop           Cycle Studio

# %%
# A csv file summarized the subway station and the addresses for next step to determine geodata
mh=pd.read_csv('NYC_subway_list.csv')
mh.head()
# Out:
#                      sub_station                              sub_address
# 0  Dyckman Street Subway Station   170 Nagle Ave, New York, NY 10034, USA
# 1       57 Street Subway Station                  New York, NY 10106, USA
# 2                       Broad St                  New York, NY 10005, USA
# 3             175 Street Station  807 W 177th St, New York, NY 10033, USA
# 4                 5 Av and 53 St                  New York, NY 10022, USA

# %%
#  Add columns 'lat'  and 'long' to mh dataframe - with random temporary numbers to get started
sLength = len(mh['sub_station'])
lat = pd.Series(np.random.randn(sLength))
long=pd.Series(np.random.randn(sLength))
mh = mh.assign(lat=lat.values)
mh = mh.assign(long=long.values)

# %%
mh=pd.read_csv('MH_subway.csv')
print(mh.shape)
mh.head()
# Out:
# (76, 4)
#                      sub_station                              sub_address  \
# 0  Dyckman Street Subway Station   170 Nagle Ave, New York, NY 10034, USA
# 1       57 Street Subway Station                  New York, NY 10106, USA
# 2                       Broad St                  New York, NY 10005, USA
# 3             175 Street Station  807 W 177th St, New York, NY 10033, USA
# 4                 5 Av and 53 St                  New York, NY 10022, USA
#
#          lat       long
# 0  40.861857 -73.924509
# 1  40.764250 -73.954525
# 2  40.730862 -73.987156
# 3  40.847991 -73.939785
# 4  40.764250 -73.954525

# %%
# removing duplicate rows and creating new set mhsub1
mhsub1=mh.drop_duplicates(subset=['lat','long'], keep="last").reset_index(drop=True)
mhsub1.shape
# Out:
# (22, 4)

# %%
latitude= man_latitude
longitude= man_longitude

map_mhsub1 = folium.Map(location=[latitude, longitude], zoom_start=12)

# add markers of subway locations to map
for lat, lng, label in zip(mhsub1['lat'], mhsub1['long'],  mhsub1['sub_station'].astype(str) ):
    label = folium.Popup(label, parse_html=True)
    folium.RegularPolygonMarker(
        [lat, lng],
        number_of_sides=6,
        radius=6,
        popup=label,
        color='red',
        fill_color='red',
        fill_opacity=2.5,
    ).add_to(map_mhsub1) 
map_mhsub1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mh_rent.head()
# Out:
#              Address             Area  Price_per_ft2  Rooms  Area-ft2  \
# 0  West 105th Street  Upper West Side           2.94    5.0      3400
# 1   East 97th Street  Upper East Side           3.57    3.0      2100
# 2  West 105th Street  Upper West Side           1.89    4.0      2800
# 3        CARMINE ST.     West Village           3.03    2.0      1650
# 4    171 W 23RD ST.           Chelsea           3.45    2.0      1450
#
#    Rent_Price        Lat       Long
# 0       10000  40.799771 -73.966213
# 1        7500  40.788585 -73.955277
# 2        5300  40.799771 -73.966213
# 3        5000  40.730523 -74.001873
# 4        5000  40.744118 -73.995299

# %%
latitude= man_latitude
longitude= man_longitude

map_manhattan_rent = folium.Map(location=[latitude, longitude], zoom_start=13.3)

# add markers to map
for lat, lng, label in zip(mh_rent['Lat'], mh_rent['Long'],'$ ' + mh_rent['Rent_Price'].astype(str)+ mh_rent['Address']):      
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=6,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_manhattan_rent) 
    
    # add markers of subway locations to map
for lat, lng, label in zip(mhsub1['lat'], mhsub1['long'],  mhsub1['sub_station'].astype(str) ):
    label = folium.Popup(label, parse_html=True)
    folium.RegularPolygonMarker(
        [lat, lng],
        number_of_sides=6,
        radius=6,
        popup=label,
        color='red',
        fill_color='red',
        fill_opacity=2.5,
    ).add_to(map_manhattan_rent) 
    
    # Adds tool to the top right
from folium.plugins import MeasureControl
map_manhattan_rent.add_child(MeasureControl())

# Measurement ruler icon tool to measure distances in map
from folium.plugins import FloatImage
url = ('https://media.licdn.com/mpr/mpr/shrinknp_100_100/AAEAAQAAAAAAAAlgAAAAJGE3OTA4YTdlLTkzZjUtNDFjYy1iZThlLWQ5OTNkYzlhNzM4OQ.jpg')
FloatImage(url, bottom=5, left=85).add_to(map_manhattan_rent)

map_manhattan_rent
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
latitude= man_latitude
longitude= man_longitude

map_mh_one = folium.Map(location=[latitude, longitude], zoom_start=13.3)

# add markers to map
for lat, lng, label in zip(mh_rent['Lat'], mh_rent['Long'],'$ ' + mh_rent['Rent_Price'].astype(str)+ ', '+mh_rent['Address']):      
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=6,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_mh_one) 
    
    # add markers of subway locations to map
for lat, lng, label in zip(mhsub1['lat'], mhsub1['long'],  mhsub1['sub_station'].astype(str) ):
    label = folium.Popup(label, parse_html=True)
    folium.RegularPolygonMarker(
        [lat, lng],
        number_of_sides=6,
        radius=6,
        popup=label,
        color='red',
        fill_color='red',
        fill_opacity=2.5,
    ).add_to(map_mh_one) 



# set color scheme for the clusters
kclusters=5
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(manhattan_merged['Latitude'], manhattan_merged['Longitude'], manhattan_merged['Neighborhood'], manhattan_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=15,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_mh_one)

    # Adds tool to the top right
from folium.plugins import MeasureControl
map_mh_one.add_child(MeasureControl())

# Measurement ruler icon tool to measure distances in map
from folium.plugins import FloatImage
url = ('https://media.licdn.com/mpr/mpr/shrinknp_100_100/AAEAAQAAAAAAAAlgAAAAJGE3OTA4YTdlLTkzZjUtNDFjYy1iZThlLWQ5OTNkYzlhNzM4OQ.jpg')
FloatImage(url, bottom=5, left=85).add_to(map_mh_one)

map_mh_one
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
## kk is the cluster number to explore
kk = 2
manhattan_merged.loc[manhattan_merged['Cluster Labels'] == kk, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]]
# Out:
#            Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0           Marble Hill           Coffee Shop        Discount Store
# 1             Chinatown    Chinese Restaurant          Cocktail Bar
# 6        Central Harlem    African Restaurant    Seafood Restaurant
# 9             Yorkville           Coffee Shop                   Gym
# 14              Clinton               Theater    Italian Restaurant
# 23                 Soho        Clothing Store              Boutique
# 26  Morningside Heights           Coffee Shop   American Restaurant
# 34         Sutton Place  Gym / Fitness Center    Italian Restaurant
# 39         Hudson Yards           Coffee Shop    Italian Restaurant
#
#      3rd Most Common Venue 4th Most Common Venue  5th Most Common Venue  \
# 0              Yoga Studio            Steakhouse        Supplement Shop
# 1       Dim Sum Restaurant   American Restaurant  Vietnamese Restaurant
# 6        French Restaurant   American Restaurant         Cosmetics Shop
# 9                      Bar    Italian Restaurant       Sushi Restaurant
# 14             Coffee Shop   American Restaurant   Gym / Fitness Center
# 23           Women's Store            Shoe Store            Men's Store
# 26                    Park             Bookstore            Pizza Place
# 34  Furniture / Home Store     Indian Restaurant           Dessert Shop
# 39                   Hotel               Theater    American Restaurant
#
#      6th Most Common Venue 7th Most Common Venue     8th Most Common Venue  \
# 0           Tennis Stadium            Shoe Store                       Gym
# 1       Salon / Barbershop          Noodle House                    Bakery
# 6       Chinese Restaurant           Event Space              Liquor Store
# 9              Pizza Place    Mexican Restaurant             Deli / Bodega
# 14                   Hotel             Wine Shop                       Spa
# 23  Furniture / Home Store    Italian Restaurant  Mediterranean Restaurant
# 26          Sandwich Place          Burger Joint                      Café
# 34     American Restaurant                Bakery                 Juice Bar
# 39                    Café  Gym / Fitness Center           Thai Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 0                   Bank     Seafood Restaurant
# 1        Bubble Tea Shop         Ice Cream Shop
# 6               Beer Bar   Gym / Fitness Center
# 9    Japanese Restaurant                    Pub
# 14                   Gym          Indie Theater
# 23           Art Gallery          Design Studio
# 26         Deli / Bodega           Tennis Court
# 34              Boutique       Sushi Restaurant
# 39            Restaurant                    Gym

# %%
## kk is the cluster number to explore
kk = 3
manhattan_merged.loc[manhattan_merged['Cluster Labels'] == kk, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]]
# Out:
#           Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 3               Inwood    Mexican Restaurant                Lounge
# 5       Manhattanville         Deli / Bodega    Italian Restaurant
# 10          Lenox Hill      Sushi Restaurant    Italian Restaurant
# 12     Upper West Side    Italian Restaurant                   Bar
# 16         Murray Hill        Sandwich Place                 Hotel
# 17             Chelsea           Coffee Shop    Italian Restaurant
# 18   Greenwich Village    Italian Restaurant      Sushi Restaurant
# 27            Gramercy    Italian Restaurant            Restaurant
# 29  Financial District           Coffee Shop                 Hotel
# 31                Noho    Italian Restaurant     French Restaurant
# 32        Civic Center  Gym / Fitness Center                Bakery
# 35          Turtle Bay    Italian Restaurant           Coffee Shop
# 36          Tudor City                  Café                  Park
# 38            Flatiron    Italian Restaurant   American Restaurant
#
#      3rd Most Common Venue          4th Most Common Venue  \
# 3              Pizza Place                           Café
# 5       Seafood Restaurant             Mexican Restaurant
# 10             Coffee Shop           Gym / Fitness Center
# 12                  Bakery  Vegetarian / Vegan Restaurant
# 16     Japanese Restaurant           Gym / Fitness Center
# 17          Ice Cream Shop                         Bakery
# 18       French Restaurant                 Clothing Store
# 27  Thrift / Vintage Store                   Cocktail Bar
# 29                     Gym                      Wine Shop
# 31            Cocktail Bar                      Gift Shop
# 32      Italian Restaurant                   Cocktail Bar
# 35              Steakhouse                       Wine Bar
# 36             Pizza Place             Mexican Restaurant
# 38                     Gym           Gym / Fitness Center
#
#    5th Most Common Venue          6th Most Common Venue 7th Most Common Venue  \
# 3               Wine Bar                         Bakery   American Restaurant
# 5       Sushi Restaurant                    Beer Garden           Coffee Shop
# 10           Pizza Place                   Burger Joint         Deli / Bodega
# 12     Indian Restaurant                    Coffee Shop        Cosmetics Shop
# 16           Coffee Shop             Salon / Barbershop          Burger Joint
# 17             Nightclub                        Theater           Art Gallery
# 18    Chinese Restaurant                           Café     Indian Restaurant
# 27            Bagel Shop                    Coffee Shop           Pizza Place
# 29            Steakhouse                            Bar    Italian Restaurant
# 31             Bookstore                  Grocery Store    Mexican Restaurant
# 32     French Restaurant                 Sandwich Place           Coffee Shop
# 35      Sushi Restaurant                          Hotel          Noodle House
# 36      Greek Restaurant               Sushi Restaurant                 Hotel
# 38           Yoga Studio  Vegetarian / Vegan Restaurant                Bakery
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 3                   Park    Frozen Yogurt Shop     Spanish Restaurant
# 5     Falafel Restaurant            Bike Trail        Other Nightlife
# 10                   Gym   Sporting Goods Shop        Thai Restaurant
# 12              Wine Bar    Mexican Restaurant       Sushi Restaurant
# 16     French Restaurant                   Bar     Italian Restaurant
# 17    Seafood Restaurant   American Restaurant                  Hotel
# 18                Bakery    Seafood Restaurant      Electronics Store
# 27    Mexican Restaurant         Grocery Store              Wine Shop
# 29           Pizza Place                  Park   Gym / Fitness Center
# 31                 Hotel      Sushi Restaurant            Coffee Shop
# 32                   Gym           Yoga Studio                   Park
# 35     Indian Restaurant   Japanese Restaurant      French Restaurant
# 36         Deli / Bodega                 Diner                Dog Run
# 38        Clothing Store        Cosmetics Shop           Cycle Studio
